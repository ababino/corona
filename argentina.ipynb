# %%
# %matplotlib widget
import os
import requests
import urllib.parse
import json
import io
from zipfile import ZipFile
from datetime import datetime, timedelta

import pandas as pd
import numpy as np
import statsmodels.api as sm
import scipy

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from sklearn import linear_model
from scipy import stats as sps
from sklearn.feature_selection import SelectFromModel
from IPython.display import display

locator = mdates.AutoDateLocator()
formatter = mdates.ConciseDateFormatter(locator)

sns.set_style("whitegrid")
GAMMA = 1/7.5

events = {}
df_dict = {}
dataset_info = {}
#may 15 last day

# %%
# %%bash
# python get_tests2.py
# Out:
# https://www.argentina.gob.ar/sites/default/files/31-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/31-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-30 00:00:00
# confirmed 16214
# new tests 4663
# https://www.argentina.gob.ar/sites/default/files/30-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/30-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-29 00:00:00
# confirmed 15419
# new tests 4921
# https://www.argentina.gob.ar/sites/default/files/29-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/29-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-28 00:00:00
# confirmed 14702
# new tests 5405
# https://www.argentina.gob.ar/sites/default/files/28-05-20-reporte-matutino-covid.pdf
# Downloading: data/argentina/28-05-20-reporte-matutino-covid.pdf
# extract text
# extract info
# date 2020-05-27 00:00:00
# confirmed 13933
# new tests 4863
# https://www.argentina.gob.ar/sites/default/files/27-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/27-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-26 00:00:00
# confirmed 13228
# new tests 3556
# https://www.argentina.gob.ar/sites/default/files/26-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/26-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-25 00:00:00
# confirmed 12628
# new tests 3194
# https://www.argentina.gob.ar/sites/default/files/25-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/25-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-24 00:00:00
# confirmed 12076
# new tests 4050
# https://www.argentina.gob.ar/sites/default/files/24-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/24-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-23 00:00:00
# confirmed 11353
# new tests 3525
# https://www.argentina.gob.ar/sites/default/files/23-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/23-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-22 00:00:00
# confirmed 10649
# new tests 4615
# https://www.argentina.gob.ar/sites/default/files/22-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/22-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-21 00:00:00
# confirmed 9931
# new tests 4589
# https://www.argentina.gob.ar/sites/default/files/21-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/21-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-20 00:00:00
# confirmed 9283
# new tests 4319
# https://www.argentina.gob.ar/sites/default/files/20-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/20-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-19 00:00:00
# confirmed 8809
# new tests 3736
# https://www.argentina.gob.ar/sites/default/files/19-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/19-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-18 00:00:00
# confirmed 8371
# new tests 2805
# https://www.argentina.gob.ar/sites/default/files/18-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/18-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-17 00:00:00
# confirmed 8068
# new tests 2609
# https://www.argentina.gob.ar/sites/default/files/17-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/17-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-16 00:00:00
# confirmed 7805
# new tests 2858
# https://www.argentina.gob.ar/sites/default/files/16-05-20_reporte_matutino_covid_19.docx.pdf
# Downloading: data/argentina/16-05-20_reporte_matutino_covid_19.docx.pdf
# extract text
# extract info
# date 2020-05-15 00:00:00
# confirmed 7479
# new tests 3469
# https://www.argentina.gob.ar/sites/default/files/15-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/15-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-14 00:00:00
# confirmed 7134
# new tests 3220
# https://www.argentina.gob.ar/sites/default/files/14-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/14-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-13 00:00:00
# confirmed 6879
# new tests 3199
# https://www.argentina.gob.ar/sites/default/files/13-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/13-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-12 00:00:00
# confirmed 6563
# new tests 2927
# https://www.argentina.gob.ar/sites/default/files/12-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/12-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-11 00:00:00
# confirmed 6278
# new tests 2389
# https://www.argentina.gob.ar/sites/default/files/11-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/11-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-10 00:00:00
# confirmed 6034
# new tests 2140
# https://www.argentina.gob.ar/sites/default/files/10-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/10-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-09 00:00:00
# confirmed 5776
# new tests 2289
# https://www.argentina.gob.ar/sites/default/files/09-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/09-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-08 00:00:00
# confirmed 5611
# new tests 2828
# https://www.argentina.gob.ar/sites/default/files/08-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/08-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-07 00:00:00
# confirmed 5371
# new tests 2703
# https://www.argentina.gob.ar/sites/default/files/07-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/07-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-06 00:00:00
# confirmed 5208
# new tests 2883
# https://www.argentina.gob.ar/sites/default/files/06-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/06-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-05 00:00:00
# confirmed 5020
# new tests 2597
# https://www.argentina.gob.ar/sites/default/files/05-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/05-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-04 00:00:00
# confirmed 4887
# new tests 1798
# https://www.argentina.gob.ar/sites/default/files/04-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/04-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-03 00:00:00
# confirmed 4783
# new tests 2107
# https://www.argentina.gob.ar/sites/default/files/03-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/03-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-02 00:00:00
# confirmed 4681
# new tests 1947
# https://www.argentina.gob.ar/sites/default/files/02-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/02-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-01 00:00:00
# confirmed 4532
# new tests 2336
# https://www.argentina.gob.ar/sites/default/files/01-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/01-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-04-30 00:00:00
# confirmed 4428
# new tests 2845
# https://www.argentina.gob.ar/sites/default/files/31-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/31-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-30 00:00:00
# confirmed 16214
# new tests 4663
# https://www.argentina.gob.ar/sites/default/files/30-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/30-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-29 00:00:00
# confirmed 15419
# new tests 4921
# https://www.argentina.gob.ar/sites/default/files/29-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/29-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-28 00:00:00
# confirmed 14702
# new tests 5405
# https://www.argentina.gob.ar/sites/default/files/28-05-20-reporte-matutino-covid.pdf
# Downloading: data/argentina/28-05-20-reporte-matutino-covid.pdf
# extract text
# extract info
# date 2020-05-27 00:00:00
# confirmed 13933
# new tests 4863
# https://www.argentina.gob.ar/sites/default/files/27-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/27-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-26 00:00:00
# confirmed 13228
# new tests 3556
# https://www.argentina.gob.ar/sites/default/files/26-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/26-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-25 00:00:00
# confirmed 12628
# new tests 3194
# https://www.argentina.gob.ar/sites/default/files/25-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/25-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-24 00:00:00
# confirmed 12076
# new tests 4050
# https://www.argentina.gob.ar/sites/default/files/24-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/24-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-23 00:00:00
# confirmed 11353
# new tests 3525
# https://www.argentina.gob.ar/sites/default/files/23-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/23-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-22 00:00:00
# confirmed 10649
# new tests 4615
# https://www.argentina.gob.ar/sites/default/files/22-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/22-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-21 00:00:00
# confirmed 9931
# new tests 4589
# https://www.argentina.gob.ar/sites/default/files/21-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/21-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-20 00:00:00
# confirmed 9283
# new tests 4319
# https://www.argentina.gob.ar/sites/default/files/20-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/20-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-19 00:00:00
# confirmed 8809
# new tests 3736
# https://www.argentina.gob.ar/sites/default/files/19-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/19-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-18 00:00:00
# confirmed 8371
# new tests 2805
# https://www.argentina.gob.ar/sites/default/files/18-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/18-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-17 00:00:00
# confirmed 8068
# new tests 2609
# https://www.argentina.gob.ar/sites/default/files/17-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/17-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-16 00:00:00
# confirmed 7805
# new tests 2858
# https://www.argentina.gob.ar/sites/default/files/16-05-20_reporte_matutino_covid_19.docx.pdf
# Downloading: data/argentina/16-05-20_reporte_matutino_covid_19.docx.pdf
# extract text
# extract info
# date 2020-05-15 00:00:00
# confirmed 7479
# new tests 3469
# https://www.argentina.gob.ar/sites/default/files/15-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/15-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-14 00:00:00
# confirmed 7134
# new tests 3220
# https://www.argentina.gob.ar/sites/default/files/14-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/14-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-13 00:00:00
# confirmed 6879
# new tests 3199
# https://www.argentina.gob.ar/sites/default/files/13-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/13-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-12 00:00:00
# confirmed 6563
# new tests 2927
# https://www.argentina.gob.ar/sites/default/files/12-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/12-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-11 00:00:00
# confirmed 6278
# new tests 2389
# https://www.argentina.gob.ar/sites/default/files/11-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/11-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-10 00:00:00
# confirmed 6034
# new tests 2140
# https://www.argentina.gob.ar/sites/default/files/10-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/10-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-09 00:00:00
# confirmed 5776
# new tests 2289
# https://www.argentina.gob.ar/sites/default/files/09-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/09-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-08 00:00:00
# confirmed 5611
# new tests 2828
# https://www.argentina.gob.ar/sites/default/files/08-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/08-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-07 00:00:00
# confirmed 5371
# new tests 2703
# https://www.argentina.gob.ar/sites/default/files/07-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/07-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-06 00:00:00
# confirmed 5208
# new tests 2883
# https://www.argentina.gob.ar/sites/default/files/06-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/06-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-05 00:00:00
# confirmed 5020
# new tests 2597
# https://www.argentina.gob.ar/sites/default/files/05-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/05-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-04 00:00:00
# confirmed 4887
# new tests 1798
# https://www.argentina.gob.ar/sites/default/files/04-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/04-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-03 00:00:00
# confirmed 4783
# new tests 2107
# https://www.argentina.gob.ar/sites/default/files/03-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/03-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-02 00:00:00
# confirmed 4681
# new tests 1947
# https://www.argentina.gob.ar/sites/default/files/02-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/02-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-01 00:00:00
# confirmed 4532
# new tests 2336
# https://www.argentina.gob.ar/sites/default/files/01-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/01-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-04-30 00:00:00
# confirmed 4428
# new tests 2845
# https://www.argentina.gob.ar/sites/default/files/30-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/30-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-29 00:00:00
# confirmed 62268
# new tests 7993
# https://www.argentina.gob.ar/sites/default/files/29-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/29-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-28 00:00:00
# confirmed 59933
# new tests 7458
# https://www.argentina.gob.ar/sites/default/files/28-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/28-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-27 00:00:00
# confirmed 57744
# new tests 7915
# https://www.argentina.gob.ar/sites/default/files/27-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/27-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-26 00:00:00
# confirmed 55343
# new tests 10315
# https://www.argentina.gob.ar/sites/default/files/26-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/26-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-25 00:00:00
# confirmed 52457
# new tests 9120
# https://www.argentina.gob.ar/sites/default/files/25-06-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/25-06-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-06-24 00:00:00
# confirmed 49851
# new tests 9258
# https://www.argentina.gob.ar/sites/default/files/24-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/24-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-23 00:00:00
# confirmed 47216
# new tests 7832
# https://www.argentina.gob.ar/sites/default/files/23-06-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/23-06-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-06-22 00:00:00
# confirmed 44931
# new tests 7120
# https://www.argentina.gob.ar/sites/default/files/22-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/22-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-21 00:00:00
# confirmed 42785
# new tests 5719
# https://www.argentina.gob.ar/sites/default/files/21-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/21-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-20 00:00:00
# confirmed 41204
# new tests 6443
# https://www.argentina.gob.ar/sites/default/files/19-06-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/19-06-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-06-18 00:00:00
# confirmed 37510
# new tests 7512
# https://www.argentina.gob.ar/sites/default/files/18-06-20_reporte_matutino_covid19.pdf
# Downloading: data/argentina/18-06-20_reporte_matutino_covid19.pdf
# extract text
# extract info
# date 2020-06-17 00:00:00
# confirmed 35552
# new tests 6477
# https://www.argentina.gob.ar/sites/default/files/17-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/17-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-16 00:00:00
# confirmed 34159
# new tests 5556
# https://www.argentina.gob.ar/sites/default/files/16-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/16-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-15 00:00:00
# confirmed 32785
# new tests 5118
# https://www.argentina.gob.ar/sites/default/files/15-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/15-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-14 00:00:00
# confirmed 31577
# new tests 5571
# https://www.argentina.gob.ar/sites/default/files/14-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/14-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-13 00:00:00
# confirmed 30295
# new tests 6046
# https://www.argentina.gob.ar/sites/default/files/13-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/13-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-12 00:00:00
# confirmed 28764
# new tests 7019
# https://www.argentina.gob.ar/sites/default/files/12-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/12-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-11 00:00:00
# confirmed 27373
# new tests 6498
# https://www.argentina.gob.ar/sites/default/files/11-06-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/11-06-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-06-10 00:00:00
# confirmed 25987
# new tests 6288
# https://www.argentina.gob.ar/sites/default/files/10-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/10-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-09 00:00:00
# confirmed 24761
# new tests 5468
# https://www.argentina.gob.ar/sites/default/files/09-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/09-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-08 00:00:00
# confirmed 23620
# new tests 4531
# https://www.argentina.gob.ar/sites/default/files/08-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/08-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-07 00:00:00
# confirmed 22794
# new tests 4607
# https://www.argentina.gob.ar/sites/default/files/7-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/7-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-06 00:00:00
# confirmed 22020
# new tests 4635
# https://www.argentina.gob.ar/sites/default/files/06-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/06-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-05 00:00:00
# confirmed 21037
# new tests 5416
# https://www.argentina.gob.ar/sites/default/files/05-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/05-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-04 00:00:00
# confirmed 20197
# new tests 5414
# https://www.argentina.gob.ar/sites/default/files/04-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/04-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-03 00:00:00
# confirmed 19268
# new tests 5501
# https://www.argentina.gob.ar/sites/default/files/03-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/03-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-02 00:00:00
# confirmed 18319
# new tests 5148
# https://www.argentina.gob.ar/sites/default/files/2-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/2-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-01 00:00:00
# confirmed 17415
# new tests 3715
# https://www.argentina.gob.ar/sites/default/files/01-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/01-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-31 00:00:00
# confirmed 16851
# new tests 4014
# https://www.argentina.gob.ar/sites/default/files/31-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/31-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-30 00:00:00
# confirmed 16214
# new tests 4663
# https://www.argentina.gob.ar/sites/default/files/30-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/30-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-29 00:00:00
# confirmed 15419
# new tests 4921
# https://www.argentina.gob.ar/sites/default/files/29-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/29-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-28 00:00:00
# confirmed 14702
# new tests 5405
# https://www.argentina.gob.ar/sites/default/files/28-05-20-reporte-matutino-covid.pdf
# Downloading: data/argentina/28-05-20-reporte-matutino-covid.pdf
# extract text
# extract info
# date 2020-05-27 00:00:00
# confirmed 13933
# new tests 4863
# https://www.argentina.gob.ar/sites/default/files/27-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/27-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-26 00:00:00
# confirmed 13228
# new tests 3556
# https://www.argentina.gob.ar/sites/default/files/26-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/26-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-25 00:00:00
# confirmed 12628
# new tests 3194
# https://www.argentina.gob.ar/sites/default/files/25-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/25-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-24 00:00:00
# confirmed 12076
# new tests 4050
# https://www.argentina.gob.ar/sites/default/files/24-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/24-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-23 00:00:00
# confirmed 11353
# new tests 3525
# https://www.argentina.gob.ar/sites/default/files/23-05-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/23-05-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-05-22 00:00:00
# confirmed 10649
# new tests 4615
# https://www.argentina.gob.ar/sites/default/files/22-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/22-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-21 00:00:00
# confirmed 9931
# new tests 4589
# https://www.argentina.gob.ar/sites/default/files/21-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/21-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-20 00:00:00
# confirmed 9283
# new tests 4319
# https://www.argentina.gob.ar/sites/default/files/20-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/20-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-19 00:00:00
# confirmed 8809
# new tests 3736
# https://www.argentina.gob.ar/sites/default/files/19-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/19-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-18 00:00:00
# confirmed 8371
# new tests 2805
# https://www.argentina.gob.ar/sites/default/files/18-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/18-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-17 00:00:00
# confirmed 8068
# new tests 2609
# https://www.argentina.gob.ar/sites/default/files/17-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/17-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-16 00:00:00
# confirmed 7805
# new tests 2858
# https://www.argentina.gob.ar/sites/default/files/16-05-20_reporte_matutino_covid_19.docx.pdf
# Downloading: data/argentina/16-05-20_reporte_matutino_covid_19.docx.pdf
# extract text
# extract info
# date 2020-05-15 00:00:00
# confirmed 7479
# new tests 3469
# https://www.argentina.gob.ar/sites/default/files/15-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/15-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-14 00:00:00
# confirmed 7134
# new tests 3220
# https://www.argentina.gob.ar/sites/default/files/14-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/14-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-13 00:00:00
# confirmed 6879
# new tests 3199
# https://www.argentina.gob.ar/sites/default/files/13-05-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/13-05-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-05-12 00:00:00
# confirmed 6563
# new tests 2927
# https://www.argentina.gob.ar/sites/default/files/12-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/12-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-11 00:00:00
# confirmed 6278
# new tests 2389
# https://www.argentina.gob.ar/sites/default/files/11-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/11-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-10 00:00:00
# confirmed 6034
# new tests 2140
# https://www.argentina.gob.ar/sites/default/files/10-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/10-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-09 00:00:00
# confirmed 5776
# new tests 2289
# https://www.argentina.gob.ar/sites/default/files/09-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/09-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-08 00:00:00
# confirmed 5611
# new tests 2828
# https://www.argentina.gob.ar/sites/default/files/08-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/08-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-07 00:00:00
# confirmed 5371
# new tests 2703
# https://www.argentina.gob.ar/sites/default/files/07-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/07-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-06 00:00:00
# confirmed 5208
# new tests 2883
# https://www.argentina.gob.ar/sites/default/files/06-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/06-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-05 00:00:00
# confirmed 5020
# new tests 2597
# https://www.argentina.gob.ar/sites/default/files/05-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/05-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-04 00:00:00
# confirmed 4887
# new tests 1798
# https://www.argentina.gob.ar/sites/default/files/04-05-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/04-05-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-03 00:00:00
# confirmed 4783
# new tests 2107
# https://www.argentina.gob.ar/sites/default/files/03-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/03-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-02 00:00:00
# confirmed 4681
# new tests 1947
# https://www.argentina.gob.ar/sites/default/files/02-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/02-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-01 00:00:00
# confirmed 4532
# new tests 2336
# https://www.argentina.gob.ar/sites/default/files/01-05-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/01-05-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-04-30 00:00:00
# confirmed 4428
# new tests 2845
# https://www.argentina.gob.ar/sites/default/files/30-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/30-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-29 00:00:00
# confirmed 62268
# new tests 7993
# https://www.argentina.gob.ar/sites/default/files/29-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/29-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-28 00:00:00
# confirmed 59933
# new tests 7458
# https://www.argentina.gob.ar/sites/default/files/28-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/28-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-27 00:00:00
# confirmed 57744
# new tests 7915
# https://www.argentina.gob.ar/sites/default/files/27-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/27-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-26 00:00:00
# confirmed 55343
# new tests 10315
# https://www.argentina.gob.ar/sites/default/files/26-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/26-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-25 00:00:00
# confirmed 52457
# new tests 9120
# https://www.argentina.gob.ar/sites/default/files/25-06-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/25-06-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-06-24 00:00:00
# confirmed 49851
# new tests 9258
# https://www.argentina.gob.ar/sites/default/files/24-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/24-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-23 00:00:00
# confirmed 47216
# new tests 7832
# https://www.argentina.gob.ar/sites/default/files/23-06-20_reporte-matutino_covid-19.pdf
# Downloading: data/argentina/23-06-20_reporte-matutino_covid-19.pdf
# extract text
# extract info
# date 2020-06-22 00:00:00
# confirmed 44931
# new tests 7120
# https://www.argentina.gob.ar/sites/default/files/22-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/22-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-21 00:00:00
# confirmed 42785
# new tests 5719
# https://www.argentina.gob.ar/sites/default/files/21-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/21-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-20 00:00:00
# confirmed 41204
# new tests 6443
# https://www.argentina.gob.ar/sites/default/files/19-06-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/19-06-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-06-18 00:00:00
# confirmed 37510
# new tests 7512
# https://www.argentina.gob.ar/sites/default/files/18-06-20_reporte_matutino_covid19.pdf
# Downloading: data/argentina/18-06-20_reporte_matutino_covid19.pdf
# extract text
# extract info
# date 2020-06-17 00:00:00
# confirmed 35552
# new tests 6477
# https://www.argentina.gob.ar/sites/default/files/17-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/17-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-16 00:00:00
# confirmed 34159
# new tests 5556
# https://www.argentina.gob.ar/sites/default/files/16-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/16-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-15 00:00:00
# confirmed 32785
# new tests 5118
# https://www.argentina.gob.ar/sites/default/files/15-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/15-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-14 00:00:00
# confirmed 31577
# new tests 5571
# https://www.argentina.gob.ar/sites/default/files/14-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/14-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-13 00:00:00
# confirmed 30295
# new tests 6046
# https://www.argentina.gob.ar/sites/default/files/13-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/13-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-12 00:00:00
# confirmed 28764
# new tests 7019
# https://www.argentina.gob.ar/sites/default/files/12-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/12-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-11 00:00:00
# confirmed 27373
# new tests 6498
# https://www.argentina.gob.ar/sites/default/files/11-06-20_reporte_matutino_covid_19.pdf
# Downloading: data/argentina/11-06-20_reporte_matutino_covid_19.pdf
# extract text
# extract info
# date 2020-06-10 00:00:00
# confirmed 25987
# new tests 6288
# https://www.argentina.gob.ar/sites/default/files/10-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/10-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-09 00:00:00
# confirmed 24761
# new tests 5468
# https://www.argentina.gob.ar/sites/default/files/09-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/09-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-08 00:00:00
# confirmed 23620
# new tests 4531
# https://www.argentina.gob.ar/sites/default/files/08-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/08-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-07 00:00:00
# confirmed 22794
# new tests 4607
# https://www.argentina.gob.ar/sites/default/files/7-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/7-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-06 00:00:00
# confirmed 22020
# new tests 4635
# https://www.argentina.gob.ar/sites/default/files/06-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/06-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-05 00:00:00
# confirmed 21037
# new tests 5416
# https://www.argentina.gob.ar/sites/default/files/05-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/05-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-04 00:00:00
# confirmed 20197
# new tests 5414
# https://www.argentina.gob.ar/sites/default/files/04-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/04-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-03 00:00:00
# confirmed 19268
# new tests 5501
# https://www.argentina.gob.ar/sites/default/files/03-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/03-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-02 00:00:00
# confirmed 18319
# new tests 5148
# https://www.argentina.gob.ar/sites/default/files/2-06-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/2-06-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-01 00:00:00
# confirmed 17415
# new tests 3715
# https://www.argentina.gob.ar/sites/default/files/01-06-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/01-06-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-05-31 00:00:00
# confirmed 16851
# new tests 4014
# https://www.argentina.gob.ar/sites/default/files/13-07-20-reporte-matutino-covid-19_0.pdf
# Downloading: data/argentina/13-07-20-reporte-matutino-covid-19_0.pdf
# extract text
# extract info
# date 2020-07-12 00:00:00
# confirmed 100166
# new tests 8114
# https://www.argentina.gob.ar/sites/default/files/12-07-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/12-07-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-07-11 00:00:00
# confirmed 97509
# new tests 10266
# https://www.argentina.gob.ar/sites/default/files/11-07-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/11-07-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-07-10 00:00:00
# confirmed 94060
# new tests 10309
# https://www.argentina.gob.ar/sites/default/files/10-07-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/10-07-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-07-09 00:00:00
# confirmed 90693
# new tests 11041
# https://www.argentina.gob.ar/sites/default/files/9-07-20_reporte_matutino_covid-19.pdf
# Downloading: data/argentina/9-07-20_reporte_matutino_covid-19.pdf
# extract text
# extract info
# date 2020-07-08 00:00:00
# confirmed 87030
# new tests 10910
# https://www.argentina.gob.ar/sites/default/files/8-07-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/8-07-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-07-07 00:00:00
# confirmed 83426
# new tests 9805
# https://www.argentina.gob.ar/sites/default/files/7-07-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/7-07-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-07-06 00:00:00
# confirmed 80447
# new tests 8487
# https://www.argentina.gob.ar/sites/default/files/6-07-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/6-07-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-07-05 00:00:00
# confirmed 77815
# new tests 6756
# https://www.argentina.gob.ar/sites/default/files/05-07-20_reporte-matutino-covid-19.pdf
# Downloading: data/argentina/05-07-20_reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-07-04 00:00:00
# confirmed 75376
# new tests 9072
# https://www.argentina.gob.ar/sites/default/files/4-07-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/4-07-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-07-03 00:00:00
# confirmed 72786
# new tests 8951
# https://www.argentina.gob.ar/sites/default/files/3-07-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/3-07-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-07-02 00:00:00
# confirmed 69941
# new tests 9323
# https://www.argentina.gob.ar/sites/default/files/02-07-2020-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/02-07-2020-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-07-01 00:00:00
# confirmed 67197
# new tests 9200
# https://www.argentina.gob.ar/sites/default/files/01-07-20-reporte-matutino-covid-19.pdf
# Downloading: data/argentina/01-07-20-reporte-matutino-covid-19.pdf
# extract text
# extract info
# date 2020-06-30 00:00:00
# confirmed 64530
# new tests 10506

# %%
dsname = 'Argentina'
df1 = pd.read_csv('data/argentina/argentina_tests.csv', parse_dates=[0],
                  index_col=0)
df2 = pd.read_csv('data/argentina/argentina_tests2.csv',
                  parse_dates=[0],
                  index_col=0)
df1.index = pd.to_datetime(df1.index) 
df2.index = pd.to_datetime(df2.index) 
df1['Date'] = pd.to_datetime(df1.index) 
df2['Date'] = pd.to_datetime(df2.index)
df2['Positives'] = df2.confirmed.diff()
df = df1.merge(df2, on='Date', how='outer').fillna(0)
df['Positives'] = df[['new_confirmed', 'Positives']].max(axis=1)
df['Tests'] = df[['new_tests_x', 'new_tests_y']].max(axis=1)
df = df[['Date', 'Positives', 'Tests']].set_index('Date')
df['Date'] = df.index


df = df[df['Date'] > '2020-04-17']
# #df = df[df.Date!='2020-06-20']
df.loc[pd.to_datetime('2020-06-19'), 'Tests'] = 8625     # total tests on 18 264604
df.loc[pd.to_datetime('2020-06-19'), 'Positives'] = 2060 # total tests on 19 273229
df.loc[pd.to_datetime('2020-06-20'), 'Positives'] = 1634 # total tests on 20 279672
df.loc[pd.to_datetime('2020-06-19'), 'Date'] = df.loc['2020-06-19'].index[0]
df['Odds'] = df.Positives / (df.Tests-df.Positives)

df = df.sort_index()
# df[df.Date=='2020-06-20'] = np.nan
# ax = df.plot.scatter(x='Date', y='Odds')
# ax.set_yscale('log')
df.tail()
# Out:
#             Positives    Tests       Date      Odds
# Date
# 2020-07-08     3604.0  10910.0 2020-07-08  0.493293
# 2020-07-09     3663.0  11041.0 2020-07-09  0.496476
# 2020-07-10     3367.0  10309.0 2020-07-10  0.485019
# 2020-07-11     3449.0  10266.0 2020-07-11  0.505941
# 2020-07-12     2657.0   8114.0 2020-07-12  0.486898

# %%
plt.close('all')
ax = df.plot(y=['Positives', 'Tests'], secondary_y=['Tests'], legend=True)
plt.tight_layout()
plt.savefig('figs/tests_and_cases.jpg', dpi=300)
plt.show()

plt.figure()
ax = sns.scatterplot(data=df, x='Date', y='Odds')
ax.set_yscale('log')
ax.set_xlim([df.Date.min(), df.Date.max()])
ax.xaxis.set_major_locator(locator)
ax.xaxis.set_major_formatter(formatter)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
class FirstInChunkSelector(object):
    '''Selects first element from each non zero chunk.'''

    def __init__(self, clf):
        self.clf = clf
        self.coef = None
        self.mask = None

    def select_coef(self):
        n_features = len(self.clf.coef_)
        no_zero = np.zeros(n_features+1)
        no_zero[1:] = self.clf.coef_ != 0
        #v = np.hstack([np.zeros(np.int(1/GAMMA-2)), np.ones(np.int(1/GAMMA-1))])
        #no_zero[1:] = np.convolve(self.clf.coef_ != 0, v, mode='same') > 0
        self.mask = np.diff(no_zero)>0
        self.mask[0] = True
        self.coef = self.clf.coef_[self.mask]
        return self.coef

    def transform(self, X):
        self.select_coef()
        return X[:, self.mask]

    def get_support(self):
        self.select_coef()
        return self.mask

    def get_number_of_features(self):
        self.select_coef()
        return sum(self.mask)


class LassoICSelector(object):
    """LASSO regression with FirstInChunk selector."""

    def __init__(self, X, y, criterion, alpha=0.05):
        self.lasso = linear_model.LassoLars(alpha=0, max_iter=100000)
        self.criterion = criterion
        self.selector = FirstInChunkSelector(self.lasso)
        self.OLS = sm.OLS
        #self.OLS = sm.RLM
        self.ols = self.OLS(y, X)

        self.ols_results = None
        self.X = X
        self.y = y
        self.final_ols = False
        self.alpha = alpha

    def transform_to_ols(self, X):
        '''Selects only the features of X are used by OLS.
        Also, adds a coloumn with ones for the intercept.
        '''

        X_new = self.selector.transform(X)
        if self.final_ols:
            X_new = X[:, self.support]
        X_new_with_cte = np.hstack([X_new, np.ones((X_new.shape[0], 1))])
        return X_new_with_cte

    def fit(self, X, y):
        '''Selects features and fits the OLS.'''

        # select features
        X_new = self.transform_to_ols(X)

        # fit ols
        self.ols = self.OLS(y, X_new)
        self.ols_results = self.ols.fit()

        # iteratively remove non signicative variables and fit again
        mask = self.ols_results.pvalues < self.alpha / len(self.ols_results.pvalues)
        mask[0] = True
        Xnew = self.transform_to_ols(X)
        Xnew = Xnew[:, mask]
        self.support = self.selector.get_support()
        self.ols = self.OLS(y, Xnew)
        self.ols_results = self.ols.fit()
        while any(self.ols_results.pvalues[1:] >= self.alpha / len(self.ols_results.pvalues)):
            mask.values[mask.values] = (self.ols_results.pvalues < self.alpha / len(self.ols_results.pvalues)).values
            mask[0] = True
            Xnew = self.transform_to_ols(X)
            Xnew = Xnew[:, mask]
            self.support = self.selector.get_support()
            self.ols = self.OLS(y, Xnew)
            self.ols_results = self.ols.fit()

        self.support[self.support] = mask[:-1]

    def fit_best_alpha(self, X, y):
        '''returns the model with the lowst cirterion.'''

        self.lasso.fit(X, y)
        alphas = self.lasso.alphas_
        self.criterions_ = np.zeros(len(alphas))
        self.log_liklehods = np.zeros(len(alphas))
        
        
        for i, alpha in enumerate(alphas):
            self.lasso.coef_ = self.lasso.coef_path_[:, i]
            self.fit(X, y)
            self.criterions_[i], self.log_liklehods[i] = self.get_criterion(self.ols.exog, y)
        
        # we use a list of tuples to find the minimum cirterion value.
        # If there are ties, we use the maximum alpha value.
        criterions_idx = list(zip(self.criterions_, alphas, range(len(alphas))))
        criterion, alpha, idx = min(criterions_idx, key=lambda x: (x[0], -x[1]))
        
        self.lasso.coef_ = self.lasso.coef_path_[:, idx]
        self.lasso.alpha = alpha
        self.fit(X, y)
        self.final_ols = True

    def predict(self, X):
        '''Predicts y useing the OLS fit.'''

        return self.ols.predict(self.ols_results.params, X)

    def log_liklihood(self, X, y):
        '''Computes the log liklihood assuming normally distributed errors.'''

        eps64 = np.finfo('float64').eps

        # residuals
        R = y - self.predict(X)
        sigma2 = np.var(R)

        loglike = -0.5 * len(R) * np.log(sigma2)
        loglike -= 0.5 * len(R) * np.log(2*np.pi) - 0.5*len(R) + 0.5
        return loglike

    def get_criterion(self, X, y):
        '''Computes AIC or BIC criterion.'''

        n_samples = X.shape[0]
        if self.criterion == 'aic':
            K = 2  # AIC
        elif self.criterion == 'bic':
            K = np.log(n_samples)
        else:
            raise ValueError('criterion should be either bic or aic')

        log_like = self.log_liklihood(X, y)
        df = X.shape[1]

        aic = K * df - 2*log_like
        self.criterion_ = aic

        return self.criterion_, log_like

# %%
dfstate = df.copy()
#dfstate = dfstate[(dfstate.Odds.notna()) & (dfstate.Odds!=0)]
# create the independent and the dependent variables
y = np.log(dfstate['Odds'])
X = np.tri(len(y))
X = np.cumsum(X, axis=0)[:, 1:]
X = X[(dfstate.Odds.notna()) & (dfstate.Odds!=0), :]
y = y[(dfstate.Odds.notna()) & (dfstate.Odds!=0)]

# create lasso instance
lics = LassoICSelector(X, y.values, 'bic', alpha=0.01)

# fit
lics.fit_best_alpha(X, y)

# %%
data = df.copy()
#data = data[(data.Odds.notna()) & (data.Odds!=0)]
# yhat = lics.ols_results.fittedvalues
y = np.log(data['Odds'])
X = np.tri(len(y))
X = np.cumsum(X, axis=0)[:, 1:]
X = X[(data.Odds.notna()) & (data.Odds!=0), :]
y = y[(data.Odds.notna()) & (data.Odds!=0)]
data = data[(data.Odds.notna()) & (data.Odds!=0)]
Xols = lics.transform_to_ols(X)
yhat = lics.ols.predict(lics.ols_results.params, Xols)
# from equation 5
odds_hat = np.exp(yhat)

# the error in yhat is
# Xols = lics.transform_to_ols(X)
(yhat_std, yhat_l, yhat_u) = wls_prediction_std(lics.ols_results, Xols)

# propagation of errors
#oddshat_std = np.array([exp_x_sigma(mu, s)[0] for mu, s in zip(yhat, yhat_std)])#odds_hat*yhat_std
#oddshat_std = exp_x_sigma(yhat, yhat_std)
oddshat_l = np.exp(yhat-2*yhat_std)
oddshat_u = np.exp(yhat+2*yhat_std)
data.loc[:, 'odds_hat'] = odds_hat
#data.loc[:, 'oddshat_std'] = oddshat_std
#data.loc[:, 'oddshat_l'] = odds_hat - 2*oddshat_std
#data.loc[:, 'oddshat_u'] = odds_hat + 2*oddshat_std
data.loc[:, 'oddshat_l'] = oddshat_l
data.loc[:, 'oddshat_u'] = oddshat_u

# use coefficients to calculate Rt
coef = np.zeros(len(data))
coef_std = np.zeros_like(coef) * np.nan
ind = np.squeeze(np.argwhere(lics.support))

# we do not use the last coefficient since it's the intercept (=log(odds_0))
coef[ind] = lics.ols_results.params[:-1]

# using equation 2, 4 and 6
data.loc[:, 'R'] = np.cumsum(coef)/GAMMA+1

# get covarinace matrix of coefficients
cov = lics.ols_results.cov_params().values

# since the values of Rts are a sum of variables, we use the formula
# of the sum of gaussian variables with a known covariance matrix
stds = [np.sqrt(cov[:n, :n].sum()) for n in range(1, cov.shape[0])]
if len(stds)==1:
    stds = stds[0]
coef_std[ind] = stds

# error propagation formula
data.loc[:, 'Rstd'] = coef_std / GAMMA

data['Rstd'] = data['Rstd'].fillna(method='ffill')
data['R_l'] = data['R'] - 2*data['Rstd']
data['R_u'] = data['R'] + 2*data['Rstd']

r_index = data.R.diff() != 0
Rts = data.loc[r_index, ['Date', 'R', 'R_l', 'R_u']]
Rts['delta'] = Rts['R_u'] - Rts['R_l']
display(Rts)
# Out:
#                  Date         R       R_l       R_u     delta
# Date
# 2020-04-18 2020-04-18  1.090550  1.003048  1.178052  0.175004
# 2020-05-04 2020-05-04  1.398970  1.347197  1.450744  0.103546
# 2020-05-23 2020-05-23  1.167863  1.148650  1.187076  0.038426

# %%
plt.close('all')

ax = data.plot(x='Date', y='R', legend=False)
ax.fill_between(data.index, data['R_u'], data['R_l'],
                facecolor='blue', alpha=0.2, label='95% CI')
#ax.vlines(events, 0, data.R_u.max(), linestyle='--')

plt.ylabel('Rt')
plt.tight_layout()
plt.savefig('figs/RtL1.jpg', dpi=300)
plt.show()


plt.figure()
ax = sns.scatterplot(x='Date', y='Odds', data=data, label='Data')
ax = sns.lineplot(x='Date', y='odds_hat', label='Fit', ax=ax, data=data)
ax.fill_between(data.index, data['oddshat_l'],
                data['oddshat_u'],
                facecolor='blue', alpha=0.1, label='95% CI')

ax.legend()
ax.set_yscale('log')

ax.xaxis.set_major_locator(locator)
ax.xaxis.set_major_formatter(formatter)

plt.ylabel('Odds')
plt.tight_layout()
ax.set_xlim(data['Date'].min(), data['Date'].max())
plt.savefig('figs/OddsL1.jpg', dpi=300)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
